# %%
import torch
import matplotlib.pyplot as plt

from PIL import Image

# %%
a = torch.load('./output/0.png.mask')
plt.imshow(a.transpose(1, 0))

# %%
b = Image.open('./output/0.png')
plt.imshow(b)

# %%
plt.figure(figsize=(15, 15))
plt.imshow(b)
plt.imshow(a.transpose(1,0), alpha=0.8)

# %%
base_image_name = './output/1.png'

a = torch.load(base_image_name + '.mask')
b = Image.open(base_image_name)

plt.figure(figsize=(15, 15))
plt.imshow(b)
plt.imshow(a.transpose(1,0), alpha=0.8)

# %%
plt.imshow(b)
